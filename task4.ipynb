# %%
# !pip install pandas
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Pandas version: 2.3.1

# %%
data=pd.read_csv("smartphone_usage.csv")
data.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  object
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  object
#  3   Occupation                 50000 non-null  object
#  4   Device_Type                50000 non-null  object
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# ...

# %%
data.isna().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %% [markdown]
# given data set is clean no null values

# %%
data1=pd.read_csv("dirty_data.csv")
data1.head()
# Out:
#    no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0    1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1    2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2    3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3    4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4    5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
#
#       specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0  Alcohol use disorder         35.998557         21.717375  ...
# 1  Alcohol use disorder         13.425118         11.002916  ...
# 2  Alcohol use disorder         29.941780         27.544684  ...
# 3  Alcohol use disorder         21.496226         21.846832  ...
# 4  Alcohol use disorder         37.775667         33.607679  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# ...

# %%
data1.isna().sum()
# Out:
# no.                       0
# sex                       0
# age                       0
# eeg.date                  0
# education                15
#                          ..
# COH.F.gamma.p.P4.r.O1     0
# COH.F.gamma.p.P4.s.O2     0
# COH.F.gamma.q.T6.r.O1     0
# COH.F.gamma.q.T6.s.O2     0
# COH.F.gamma.r.O1.s.O2     0
# Length: 1149, dtype: int64

# %%
data1.isna()
# Out:
#        no.    sex    age  eeg.date  education     IQ  main.disorder  \
# 0    False  False  False     False       True   True          False
# 1    False  False  False     False      False  False          False
# 2    False  False  False     False      False  False          False
# 3    False  False  False     False      False  False          False
# 4    False  False  False     False      False  False          False
# ..     ...    ...    ...       ...        ...    ...            ...
# 940  False  False  False     False      False  False          False
# 941  False  False  False     False      False  False          False
# 942  False  False  False     False      False  False          False
# 943  False  False  False     False      False  False          False
# 944  False  False  False     False      False  False          False
#
#      specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0                False             False             False  ...
# ...

# %%
data1.isna().sum()
# Out:
# no.                       0
# sex                       0
# age                       0
# eeg.date                  0
# education                15
#                          ..
# COH.F.gamma.p.P4.r.O1     0
# COH.F.gamma.p.P4.s.O2     0
# COH.F.gamma.q.T6.r.O1     0
# COH.F.gamma.q.T6.s.O2     0
# COH.F.gamma.r.O1.s.O2     0
# Length: 1149, dtype: int64

# %%
data1.dropna()
# Out:
# Empty DataFrame
# ...

# %%
data1
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# ...

# %%
data1[data1.isna().any(axis=1)]
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# ...

# %%
data_min=data1.iloc[:,:30]
data_min
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# ...

# %%
data_min[data_min.isna().any(axis=1)]
# Out:
#      no. sex    age    eeg.date  education     IQ  \
# 0      1   M  57.00   2012.8.30        NaN    NaN
# 17    18   M  30.00   2013.9.27        NaN   86.0
# 21    22   M  20.00  2014.10.23        NaN  116.0
# 33    34   F  19.26    2013.8.5       12.0    NaN
# 38    39   F  19.47   2014.5.26       12.0    NaN
# 42    43   F  32.94  2014.10.16       16.0    NaN
# 43    44   F  22.65   2014.11.8       13.0    NaN
# 60    61   M  34.00   2016.3.10       12.0    NaN
# 92    93   F  39.18    2017.3.3       16.0    NaN
# 93    94   F  28.42   2017.3.20        9.0    NaN
# 155  156   M  18.00   2013.12.7        NaN  103.0
# 173  174   M  23.00  2015.11.14        NaN  113.0
# 223  224   M  19.00   2016.7.12       12.0    NaN
# 225  226   M  20.00   2016.9.13       13.0    NaN
# 234  235   M  20.00  2017.11.22       13.0    NaN
# 269  270   M  25.00   2015.9.23        NaN   85.0
# 270  271   M  34.00   2015.9.21        NaN  120.0
# 278  279   M  21.00   2016.5.13       15.0    NaN
# ...

# %%
data_min.fillna(300, inplace=True   )
data_min
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30      200.0  200.0  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# ...

# %%
data1=pd.read_csv("dirty_data.csv")
data_min=data1.iloc[:,:30]
data_min
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# ...

# %%
data_min.isna().sum()
# Out:
# no.                   0
# sex                   0
# age                   0
# eeg.date              0
# education            15
# IQ                   13
# main.disorder         0
# specific.disorder     0
# AB.A.delta.a.FP1      0
# AB.A.delta.b.FP2      0
# AB.A.delta.c.F7       0
# AB.A.delta.d.F3       0
# AB.A.delta.e.Fz       0
# AB.A.delta.f.F4       0
# AB.A.delta.g.F8       0
# AB.A.delta.h.T3       0
# AB.A.delta.i.C3       0
# AB.A.delta.j.Cz       0
# AB.A.delta.k.C4       0
# AB.A.delta.l.T4       0
# AB.A.delta.m.T5       0
# AB.A.delta.n.P3       0
# AB.A.delta.o.Pz       0
# AB.A.delta.p.P4       0
# AB.A.delta.q.T6       0
# AB.A.delta.r.O1       0
# AB.A.delta.s.O2       0
# AB.B.theta.a.FP1      0
# AB.B.theta.b.FP2      0
# AB.B.theta.c.F7       0
# dtype: int64

# %%
print(data_min.duplicated().sum())
# Out:
# 0

# %% [markdown]
# in the above it impliews there are no duplicates

# %%
data_min['education'].dtype
# Out:
# dtype('O')

# %%
data_min['education']=pd.to_numeric(data_min['education'], errors='coerce') 

data_min['education'].dtype
# Out:
# dtype('float64')

# %%
mean_edu=data_min['education'].mean()
mean_edu
# Out:
# np.float64(13.478964401294498)

# %%
data_min['education']=data_min['education'].fillna(mean_edu)
data_min.isna().sum()
# Out:
# no.                   0
# sex                   0
# age                   0
# eeg.date              0
# education             0
# IQ                   13
# main.disorder         0
# specific.disorder     0
# AB.A.delta.a.FP1      0
# AB.A.delta.b.FP2      0
# AB.A.delta.c.F7       0
# AB.A.delta.d.F3       0
# AB.A.delta.e.Fz       0
# AB.A.delta.f.F4       0
# AB.A.delta.g.F8       0
# AB.A.delta.h.T3       0
# AB.A.delta.i.C3       0
# AB.A.delta.j.Cz       0
# AB.A.delta.k.C4       0
# AB.A.delta.l.T4       0
# AB.A.delta.m.T5       0
# AB.A.delta.n.P3       0
# AB.A.delta.o.Pz       0
# AB.A.delta.p.P4       0
# AB.A.delta.q.T6       0
# AB.A.delta.r.O1       0
# AB.A.delta.s.O2       0
# AB.B.theta.a.FP1      0
# AB.B.theta.b.FP2      0
# AB.B.theta.c.F7       0
# dtype: int64

# %%
data_min['IQ'].dtype
# Out:
# dtype('float64')

# %%
mean_IQ=data_min['IQ'].mean()
mean_IQ
# Out:
# np.float64(101.5804721030043)

# %%
data_min['IQ']=data_min['IQ'].fillna(mean_IQ)
data_min.isna().sum()
# Out:
# no.                  0
# sex                  0
# age                  0
# eeg.date             0
# education            0
# IQ                   0
# main.disorder        0
# specific.disorder    0
# AB.A.delta.a.FP1     0
# AB.A.delta.b.FP2     0
# AB.A.delta.c.F7      0
# AB.A.delta.d.F3      0
# AB.A.delta.e.Fz      0
# AB.A.delta.f.F4      0
# AB.A.delta.g.F8      0
# AB.A.delta.h.T3      0
# AB.A.delta.i.C3      0
# AB.A.delta.j.Cz      0
# AB.A.delta.k.C4      0
# AB.A.delta.l.T4      0
# AB.A.delta.m.T5      0
# AB.A.delta.n.P3      0
# AB.A.delta.o.Pz      0
# AB.A.delta.p.P4      0
# AB.A.delta.q.T6      0
# AB.A.delta.r.O1      0
# AB.A.delta.s.O2      0
# AB.B.theta.a.FP1     0
# AB.B.theta.b.FP2     0
# AB.B.theta.c.F7      0
# dtype: int64

# %%
data_min.isna().sum()
# Out:
# no.                  0
# sex                  0
# age                  0
# eeg.date             0
# education            0
# IQ                   0
# main.disorder        0
# specific.disorder    0
# AB.A.delta.a.FP1     0
# AB.A.delta.b.FP2     0
# AB.A.delta.c.F7      0
# AB.A.delta.d.F3      0
# AB.A.delta.e.Fz      0
# AB.A.delta.f.F4      0
# AB.A.delta.g.F8      0
# AB.A.delta.h.T3      0
# AB.A.delta.i.C3      0
# AB.A.delta.j.Cz      0
# AB.A.delta.k.C4      0
# AB.A.delta.l.T4      0
# AB.A.delta.m.T5      0
# AB.A.delta.n.P3      0
# AB.A.delta.o.Pz      0
# AB.A.delta.p.P4      0
# AB.A.delta.q.T6      0
# AB.A.delta.r.O1      0
# AB.A.delta.s.O2      0
# AB.B.theta.a.FP1     0
# AB.B.theta.b.FP2     0
# AB.B.theta.c.F7      0
# dtype: int64
